# %%
import matplotlib.pyplot as plt
import numpy as np

#Generate some random data
data = np.random.randn(1000)

#create a density plot
plt.hist(data,density=True,bins=30,alpha=0.5)

#add tabels and title
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Density Plot')

#show the plot
plt.show()

# %%
import seaborn as sns

#Load the example titanic dataset
titanic = sns.load_dataset('titanic')

#Create a FacetGrid with two categorial variables:class and sex
grid = sns.FacetGrid(titanic,row='class',col='sex')


#map a plot type to the grid using the desired variable:age
grid.map(sns.histplot,'age')


#set common labels for y-axis and x axis
grid.set_axis_labels('Age','Count')


grid.set_titles(row_template='{row_name} Class',col_template='{col_name}')

plt.show() #show the plot

# %%
import matplotlib.pyplot as plt
import numpy as np

#Generate some random data
x= np.linspace(0, 10 ,100)
y1=np.sin(x)
y2= np.cos(x)
y3= np.tan(x)

#Generate a figures with subplots
fig, axes =plt.subplots(3, 1,figsize=(8 , 15))

#plot data on each subplot
axes[0].plot(x, y1, color='red')
axes[0].set_title('plot1 1: Sin(x)')
axes[0].set_xlabel('x')
axes[0].set_ylabel('y')

axes[1].plot(x, y2, color='green')
axes[1].set_title('Plot 2: Cos(x)')
axes[1].set_xlabel('x')
axes[1].set_ylabel('y')

ae

#Adjusting spacing between subplots
plt.tight_layout()

#show the plot
plt.show()

# %%
importb plotly.graph_object as go
import plotly.subplots as sp

#Create data for the pannels
x =[1,2,3,4,5];y1 =[1,4,9,16,25];y2=[10,8,6,4,2];y3=[1,8,27,64,125]

#create subplots with panels
fig.sp.make_subplots(rows=1,cols=3,plt.subplot_titles=('panel0'))
